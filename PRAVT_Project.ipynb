# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.io import loadmat

# %%
df = loadmat("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\I80dataset1_lanes.mat")

# %%
df
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Tue Jan 13 09:55:45 2009',
#  '__version__': '1.0',
#  '__globals__': [],
#  'I80dataset1_lane1': array([[ 2.00000000e+00,  3.38000000e+02,  4.15000000e+02, ...,
#          -9.99900000e+03,  0.00000000e+00,  1.43000000e+01],
#         [ 2.00000000e+00,  3.39000000e+02,  4.15000000e+02, ...,
#          -9.99900000e+03,  0.00000000e+00,  2.01400248e+01],
#         [ 2.00000000e+00,  3.40000000e+02,  4.15000000e+02, ...,
#          -9.99900000e+03,  0.00000000e+00,  1.49999871e+01],
#         ...,
#         [ 3.36600000e+03,  3.22700000e+03,  2.91000000e+02, ...,
#           9.90270000e+01,  0.00000000e+00,  6.32578151e+01],
#         [ 3.36600000e+03,  3.22800000e+03,  2.91000000e+02, ...,
#           9.89560000e+01,  0.00000000e+00,  6.27432832e+01],
#         [ 3.36600000e+03,  3.22900000e+03,  2.91000000e+02, ...,
#           9.88000000e+01,  0.00000000e+00,  6.22187262e+01]]),
# ...

# %%
df.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'I80dataset1_lane1', 'I80dataset1_lane2', 'I80dataset1_lane3', 'I80dataset1_lane4', 'I80dataset1_lane5', 'I80dataset1_lane6', 'I80dataset1_lane7'])

# %%
df["I80dataset1_lane1"].shape
# Out:
# (104412, 23)

# %%
df["I80dataset1_lane2"].shape
# Out:
# (240365, 23)

# %%
df["I80dataset1_lane3"].shape
# Out:
# (198779, 23)

# %%
df["I80dataset1_lane4"].shape
# Out:
# (243914, 23)

# %%
df["I80dataset1_lane5"].shape
# Out:
# (216593, 23)

# %%
df["I80dataset1_lane6"].shape
# Out:
# (228525, 23)

# %%
df["I80dataset1_lane7"].shape
# Out:
# (30050, 23)

# %%
X=df["I80dataset1_lane1"]

# %%
X
# Out:
# array([[ 2.00000000e+00,  3.38000000e+02,  4.15000000e+02, ...,
#         -9.99900000e+03,  0.00000000e+00,  1.43000000e+01],
#        [ 2.00000000e+00,  3.39000000e+02,  4.15000000e+02, ...,
#         -9.99900000e+03,  0.00000000e+00,  2.01400248e+01],
#        [ 2.00000000e+00,  3.40000000e+02,  4.15000000e+02, ...,
#         -9.99900000e+03,  0.00000000e+00,  1.49999871e+01],
#        ...,
#        [ 3.36600000e+03,  3.22700000e+03,  2.91000000e+02, ...,
#          9.90270000e+01,  0.00000000e+00,  6.32578151e+01],
#        [ 3.36600000e+03,  3.22800000e+03,  2.91000000e+02, ...,
#          9.89560000e+01,  0.00000000e+00,  6.27432832e+01],
#        [ 3.36600000e+03,  3.22900000e+03,  2.91000000e+02, ...,
#          9.88000000e+01,  0.00000000e+00,  6.22187262e+01]])

# %%
df1=pd.DataFrame(X)
df1.to_csv("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\P1.csv")

# %%
df2=pd.read_csv("P1.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0    0      1      2          3      4       5            6  \
# 0           0  2.0  338.0  415.0  15.991306  6.124  66.048  6042829.205
# 1           1  2.0  339.0  415.0  15.991333  6.125  68.062  6042828.958
# 2           2  2.0  340.0  415.0  15.991361  6.126  69.562  6042828.774
# 3           3  2.0  341.0  415.0  15.991389  6.125  71.563  6042828.527
# 4           4  2.0  342.0  415.0  15.991417  6.125  73.062  6042828.343
#
#              7     8  ...   13    14   15     16    17         18      19  \
# 0  2133134.007  15.3  ...  1.0  44.0  0.0  78.29  5.48   4.511637 -9999.0
# 1  2133135.991  15.3  ...  1.0  44.0  0.0  77.27  5.40  10.330023 -9999.0
# 2  2133137.480  15.3  ...  1.0  44.0  0.0  76.69  5.36   5.289078 -9999.0
# 3  2133139.465  15.3  ...  1.0  44.0  0.0  75.46  5.28  10.668893 -9999.0
# 4  2133140.953  15.3  ...  1.0  44.0  0.0  74.62  5.22   6.186927 -9999.0
#
#        20   21         22
# 0 -9999.0  0.0  14.300000
# 1 -9999.0  0.0  20.140025
# ...

# %%
df2.shape
# Out:
# (104412, 24)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104412 entries, 0 to 104411
# Data columns (total 24 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  104412 non-null  int64
#  1   0           104412 non-null  float64
#  2   1           104412 non-null  float64
#  3   2           104412 non-null  float64
#  4   3           104412 non-null  float64
#  5   4           104412 non-null  float64
#  6   5           104412 non-null  float64
#  7   6           104412 non-null  float64
#  8   7           104412 non-null  float64
#  9   8           104412 non-null  float64
#  10  9           104412 non-null  float64
#  11  10          104412 non-null  float64
#  12  11          104412 non-null  float64
#  13  12          104412 non-null  float64
#  14  13          104412 non-null  float64
#  15  14          104412 non-null  float64
#  16  15          104412 non-null  float64
#  17  16          104412 non-null  float64
# ...

# %%
df3 = loadmat("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\I80dataset2_lanes.mat")

# %%
df3.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'I80dataset2_lane1', 'I80dataset2_lane2', 'I80dataset2_lane3', 'I80dataset2_lane4', 'I80dataset2_lane5', 'I80dataset2_lane6', 'I80dataset2_lane7'])

# %%
X1=df3["I80dataset2_lane1"]

# %%
X1
print(type(X1))
# Out:
# <class 'numpy.ndarray'>

# %%
df3["I80dataset2_lane1"].shape
# Out:
# (144670, 23)

# %%
df3["I80dataset2_lane2"].shape
# Out:
# (278116, 23)

# %%
df3["I80dataset2_lane3"].shape
# Out:
# (239912, 23)

# %%
df3["I80dataset2_lane4"].shape
# Out:
# (306135, 23)

# %%
df3["I80dataset2_lane5"].shape
# Out:
# (263779, 23)

# %%
df3["I80dataset2_lane6"].shape
# Out:
# (262471, 23)

# %%
df3["I80dataset2_lane7"].shape
# Out:
# (54822, 23)

# %%
df5 = loadmat("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\I80dataset3_lanes.mat")

# %%
df5.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'I80dataset3_lane1', 'I80dataset3_lane2', 'I80dataset3_lane3', 'I80dataset3_lane4', 'I80dataset3_lane5', 'I80dataset3_lane6', 'I80dataset3_lane7'])

# %%
df5["I80dataset3_lane1"].shape
# Out:
# (155812, 23)

# %%
df5["I80dataset3_lane2"].shape
# Out:
# (311545, 23)

# %%
df5["I80dataset3_lane3"].shape
# Out:
# (280802, 23)

# %%
df5["I80dataset3_lane4"].shape
# Out:
# (329961, 23)

# %%
df5["I80dataset3_lane5"].shape
# Out:
# (305436, 23)

# %%
df5["I80dataset3_lane6"].shape
# Out:
# (299936, 23)

# %%
df5["I80dataset3_lane7"].shape
# Out:
# (70295, 23)

# %%
df6 = loadmat("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\ReConDataI80.mat")

# %%
df6.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'PRAReconI80', 'PRAReconI80_lane1', 'PRAReconI80_lane2', 'PRAReconI80_lane3', 'PRAReconI80_lane4', 'PRAReconI80_lane5', 'PRAReconI80_lane6', 'PRAReconI80_lane7', 'ReConDataI80'])

# %%
Y=df6['PRAReconI80_lane1']

# %%
df6["PRAReconI80_lane1"].shape
# Out:
# (82397, 23)

# %%
df6["PRAReconI80_lane2"].shape
# Out:
# (200316, 23)

# %%
df6["PRAReconI80_lane3"].shape
# Out:
# (166556, 23)

# %%
df6["PRAReconI80_lane4"].shape
# Out:
# (202079, 23)

# %%
df6["PRAReconI80_lane5"].shape
# Out:
# (178888, 23)

# %%
df6["PRAReconI80_lane6"].shape
# Out:
# (194568, 23)

# %%
df6["PRAReconI80_lane7"].shape
# Out:
# (30680, 23)

# %%
df6["PRAReconI80"].shape
# Out:
# (1055801, 23)

# %%
df6["ReConDataI80"].shape
# Out:
# (1055801, 11)

# %%
Z=df6["ReConDataI80"]
I=pd.DataFrame(Z)
I.to_csv("TP.csv")

# %%
df["__header__"]
# Out:
# b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Tue Jan 13 09:55:45 2009'

# %%
df7=pd.DataFrame(Y)
df7.to_csv("C:\\Users\\Sudhir Kumar\\OneDrive\\Desktop\\Machine Learning\\P2.csv")
